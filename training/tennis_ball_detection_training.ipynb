# %% [markdown]
# # Training Done in Google Colab (Using NVIDIA A100)

# %%
# %pip install roboflow
# %pip install ultralytics

from roboflow import Roboflow
rf = Roboflow(api_key="j9x8RaR0BPdnUGGJuRfJ")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov11")

# %%
# !yolo detect train model=yolo11x.pt data={dataset.location}/data.yaml imgsz=640 epochs=100

# %% [markdown]
# The code above was run in Google Colab, and the finetuned model for tennis ball detection is saved as yolo11x_best_tennis_ball_detector.pt
